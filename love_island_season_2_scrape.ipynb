# %%
from bs4 import BeautifulSoup
import requests
import csv
#print(response.status_code)

url = "https://loveisland.fandom.com/wiki/Love_Island_(Season_2)"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

tables = soup.find_all("table", {"class": "wikitable"})
islanders = tables[0]

rows = islanders.findAll("tr")

contenstant_data = []

for row in rows:
    tds = row.find_all("td")

    for count, td in enumerate(tds):
        contestant = {}
        text = td.get_text()
        text = text.strip('\n')

        match count:
            case 0:
                #hex color
                pass
            case 1:
                #name and href
                contestant.update({'name': text})
            case 2:
                #age
                contestant.update({'age': text})
            case 3:
                #hometown
                contestant.update({'hometown': text})
            case 4:
                #date entered
                contestant.update({'date_entered': text})
            case 5:
                #status on the island
                if text:
                    contestant.update({'status': text})

        if bool(contestant):
            contenstant_data.append(contestant)

        print(contestant)
# Out:
# {}
# {'name': 'Cara De La Hoyde'}
# {'age': '26'}
# {'hometown': 'Kent, England'}
# {'date_entered': 'Day 1'}
# {'status': 'Winner(Day 45)'}
# {}
# {'name': 'Nathan Massey'}
# {'age': '25'}
# {'hometown': 'Essex, England'}
# {'date_entered': 'Day 1'}
# {}
# {'name': 'Alex Bowen'}
# {'age': '24'}
# {'hometown': 'Birmingham, England'}
# {'date_entered': 'Day 18'}
# {'status': 'Runner-Up(Day 45)'}
# {}
# {'name': 'Olivia Buckland'}
# {'age': '22'}
# {'hometown': 'Essex, England'}
# {'date_entered': 'Day 1'}
# {}
# {'name': 'Kady McDermott'}
# {'age': '20'}
# {'hometown': 'Stevenage, England'}
# {'date_entered': 'Day 3'}
# {'status': '3rd Place(Day 45)'}
# {}
# {'name': 'Scott Thomas'}
# {'age': '28'}
# {'hometown': 'Manchester, England'}
# {'date_entered': 'Day 1'}
# {'status': '3rd Place(Day 45)'}
# {}
# {'name': 'Adam Maxted'}
# {'age': '24'}
# {'hometown': 'Belfast, Northern Ireland'}
# {'date_entered': 'Day 11'}
# {'status': '4th Place(Day 45)'}
# {}
# {'name': 'Katie Salmon'}
# {'age': '20'}
# {'hometown': 'The Wirral, England'}
# {'date_entered': 'Day 34'}
# {}
# {'name': 'Emma Jane Woodham'}
# {'age': '19'}
# {'hometown': 'Oxford, England'}
# {'date_entered': 'Day 27'}
# {'status': 'Dumped(Day 41)'}
# {}
# {'name': 'Terry Walsh'}
# {'age': '28'}
# {'hometown': 'Surrey, England'}
# {'date_entered': 'Day 3'}
# {}
# {'name': 'Adam Jukes'}
# {'age': '23'}
# {'hometown': 'Manchester, England'}
# {'date_entered': 'Day 34'}
# {}
# {'name': 'Lauren Whiteside'}
# {'age': '25'}
# {'hometown': 'Blackpool, England'}
# {'date_entered': 'Day 37'}
# {}
# {'name': 'Tina Stinnes'}
# {'age': '21'}
# {'hometown': 'London, England'}
# {'date_entered': 'Day 20'}
# {'status': 'Dumped(Day 40)'}
# {}
# {'name': 'Sophie Gradon'}
# {'age': '30'}
# {'hometown': 'Newcastle, England'}
# {'date_entered': 'Day 1'}
# {'status': 'Walked(Day 39)'}
# {}
# {'name': 'Troy Frith'}
# {'age': '23'}
# {'hometown': 'Kent, England'}
# {'date_entered': 'Day 30'}
# {'status': 'Dumped(Day 37)'}
# {}
# {'name': 'Tom Powell'}
# {'age': '24'}
# {'hometown': 'Port Talbot, Wales'}
# {'date_entered': 'Day 1'}
# {'status': 'Dumped(Day 33)'}
# {}
# {'name': 'Liana Isadora Van Riel'}
# {'age': '20'}
# {'hometown': 'Exeter, England'}
# {'date_entered': 'Day 20'}
# {}
# {'name': 'Oliver Maxwell Fernandez'}
# {'age': '25'}
# {'hometown': 'Hertfordshire, England'}
# {'date_entered': 'Day 30'}
# {'status': 'Dumped(Day 31)'}
# {}
# {'name': 'Malin Andersson'}
# {'age': '23'}
# {'hometown': 'Milton Keynes, England'}
# {'date_entered': 'Day 1'}
# {'status': 'Dumped(Day 25)'}
# {}
# {'name': 'Zara Holland'}
# {'age': '20'}
# {'hometown': 'Hull, England'}
# {'date_entered': 'Day 1'}
# {'status': 'Walked(Day 22)'}
# {}
# {'name': 'James Khan'}
# {'age': '20'}
# {'hometown': 'Teddington, England'}
# {'date_entered': 'Day 18'}
# {'status': 'Dumped(Day 20)'}
# {}
# {'name': 'Rykard Jenkins'}
# {'age': '25'}
# {'hometown': 'Kent, England'}
# {'date_entered': 'Day 1'}
# {'status': 'Walked(Day 15)'}
# {}
# {'name': 'Daniel Lukakis'}
# {'age': '23'}
# {'hometown': 'London, England'}
# {'date_entered': 'Day 1'}
# {'status': 'Dumped(Day 15)'}
# {}
# {'name': 'Rachel Fenton'}
# {'age': '23'}
# {'hometown': 'Hampshire, England'}
# {'date_entered': 'Day 7'}
# {}
# {'name': 'Malia Arkian'}
# {'age': '26'}
# {'hometown': 'Wilmslow, England'}
# {'date_entered': 'Day 7'}
# {'status': 'Removed(Day 7)'}
# {}
# {'name': 'Javi Shephard'}
# {'age': '27'}
# {'hometown': 'York, England'}
# {'date_entered': 'Day 1'}
# {'status': 'Dumped(Day 6)'}

# %%
soup = BeautifulSoup(response.text)

#islander_info_th = soup.find_all("th", attrs={'class': 'headerSort'})
islander_info_th = soup.find_all("th")
islander_info_td = soup.find_all("td")

#print(soup)
#print(islander_info_th)
print((islander_info_td))
